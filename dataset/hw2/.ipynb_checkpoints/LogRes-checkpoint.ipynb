# %% [markdown]
# # Homework 2 - Logistic Regression Dataset
# This is a clustering dataset for practicing logistic regression
#
# <!---
# url: https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/telemonitoring/parkinsons_updrs.data
# -->

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Basic IO
filename = 'log_reg/parkinsons.csv'
dataset  = pd.read_csv(filename)

# Randomize Dataset
dataset = dataset.sample(frac=1,random_state=32).reset_index()
dataset.head()
# Out:
#    index  subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0   2179        16   65    0    166.430       9.7017       23.105    0.00504
# 1   3630        27   57    1    182.480      12.0000       18.979    0.00440
# 2   2184        16   65    0     33.426       8.6244       16.127    0.00522
# 3   2096        15   65    0    110.510      15.0000       20.491    0.00263
# 4   2140        16   65    0     47.427       8.4671       16.599    0.00645
#
#    Jitter(Abs)  Jitter:RAP   ...     Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0     0.000051     0.00191   ...           0.330       0.02017       0.02183
# 1     0.000024     0.00198   ...           0.203       0.01211       0.01503
# 2     0.000051     0.00229   ...           0.196       0.01015       0.01311
# 3     0.000015     0.00123   ...           0.074       0.00441       0.00481
# 4     0.000065     0.00253   ...           0.240       0.00916       0.01363
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE
# 0        0.02708      0.06052  0.026663  20.372  0.63640  0.68118  0.21368
# 1        0.01850      0.03633  0.005092  24.824  0.52478  0.72423  0.23120
# 2        0.01879      0.03044  0.019854  24.055  0.55911  0.69461  0.22907
# 3        0.00680      0.01324  0.007946  27.401  0.55112  0.54453  0.09978
# 4        0.03271      0.02748  0.016993  20.423  0.55699  0.70011  0.25182
#
# [5 rows x 23 columns]

# %%
dataset.drop(['index','subject#','motor_UPDRS'], axis=1, inplace=True)
dataset.head()
# Out:
#    age  sex  test_time  total_UPDRS  Jitter(%)  Jitter(Abs)  Jitter:RAP  \
# 0   65    0    166.430       23.105    0.00504     0.000051     0.00191
# 1   57    1    182.480       18.979    0.00440     0.000024     0.00198
# 2   65    0     33.426       16.127    0.00522     0.000051     0.00229
# 3   65    0    110.510       20.491    0.00263     0.000015     0.00123
# 4   65    0     47.427       16.599    0.00645     0.000065     0.00253
#
#    Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0      0.00200     0.00574  0.03772        0.330       0.02017       0.02183
# 1      0.00237     0.00593  0.02329        0.203       0.01211       0.01503
# 2      0.00191     0.00686  0.02180        0.196       0.01015       0.01311
# 3      0.00125     0.00368  0.00878        0.074       0.00441       0.00481
# 4      0.00323     0.00759  0.02675        0.240       0.00916       0.01363
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE
# 0        0.02708      0.06052  0.026663  20.372  0.63640  0.68118  0.21368
# 1        0.01850      0.03633  0.005092  24.824  0.52478  0.72423  0.23120
# 2        0.01879      0.03044  0.019854  24.055  0.55911  0.69461  0.22907
# 3        0.00680      0.01324  0.007946  27.401  0.55112  0.54453  0.09978
# 4        0.03271      0.02748  0.016993  20.423  0.55699  0.70011  0.25182

# %%
cols = dataset.columns.tolist()
cols
# Out:
# ['age',
#  'sex',
#  'test_time',
#  'total_UPDRS',
#  'Jitter(%)',
#  'Jitter(Abs)',
#  'Jitter:RAP',
#  'Jitter:PPQ5',
#  'Jitter:DDP',
#  'Shimmer',
#  'Shimmer(dB)',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'Shimmer:APQ11',
#  'Shimmer:DDA',
#  'NHR',
#  'HNR',
#  'RPDE',
#  'DFA',
#  'PPE']

# %%
new_cols = cols[0:3] + cols[4:] + [cols[3]]
new_cols
# Out:
# ['age',
#  'sex',
#  'test_time',
#  'Jitter(%)',
#  'Jitter(Abs)',
#  'Jitter:RAP',
#  'Jitter:PPQ5',
#  'Jitter:DDP',
#  'Shimmer',
#  'Shimmer(dB)',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'Shimmer:APQ11',
#  'Shimmer:DDA',
#  'NHR',
#  'HNR',
#  'RPDE',
#  'DFA',
#  'PPE',
#  'total_UPDRS']

# %%
df = dataset[new_cols]
df.head()
# Out:
#    age  sex  test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 0   65    0    166.430    0.00504     0.000051     0.00191      0.00200
# 1   57    1    182.480    0.00440     0.000024     0.00198      0.00237
# 2   65    0     33.426    0.00522     0.000051     0.00229      0.00191
# 3   65    0    110.510    0.00263     0.000015     0.00123      0.00125
# 4   65    0     47.427    0.00645     0.000065     0.00253      0.00323
#
#    Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0     0.00574  0.03772        0.330       0.02017       0.02183
# 1     0.00593  0.02329        0.203       0.01211       0.01503
# 2     0.00686  0.02180        0.196       0.01015       0.01311
# 3     0.00368  0.00878        0.074       0.00441       0.00481
# 4     0.00759  0.02675        0.240       0.00916       0.01363
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE  \
# 0        0.02708      0.06052  0.026663  20.372  0.63640  0.68118  0.21368
# 1        0.01850      0.03633  0.005092  24.824  0.52478  0.72423  0.23120
# 2        0.01879      0.03044  0.019854  24.055  0.55911  0.69461  0.22907
# 3        0.00680      0.01324  0.007946  27.401  0.55112  0.54453  0.09978
# 4        0.03271      0.02748  0.016993  20.423  0.55699  0.70011  0.25182
#
#    total_UPDRS
# 0       23.105
# 1       18.979
# 2       16.127
# 3       20.491
# 4       16.599

# %%
# Split Into Training & Testing Sets
train, test  = train_test_split(dataset,test_size=0.30)
train, valid = train_test_split(train, test_size=0.20)

# Write to Text Data
train.to_csv('log_reg/train_parkinsons.csv',index=False)
train.to_csv('log_reg/valid_parkinsons.csv',index=False)
test.to_csv('log_reg/test_parkinsons.csv',index=False)

# %%
print 'Number of Instances Per Set'
print 'Training Set:   %d'%(len(train))
print 'Validation Set: %d'%(len(valid))
print 'Testing Set:    %d'%(len(test))
# Out:
# Number of Instances Per Set
# Training Set:   3289
# Validation Set: 823
# Testing Set:    1763
